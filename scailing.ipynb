# %% [markdown]
# <a href="https://colab.research.google.com/github/taetae991202/Practice_sklearn/blob/main/scailing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statsmodels.api as sm

housing = pd.read_csv('/content/drive/MyDrive/지능형시스템/housing.data', header=None, sep='\s+')
housing.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT','MEDV']
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
model1 = sm.OLS.from_formula("MEDV ~ " + "+".join(housing.columns), data=housing)
result1 = model1.fit()
print(result1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 7.948e+30
# Date:                Sat, 24 Jun 2023   Prob (F-statistic):               0.00
# Time:                        11:14:46   Log-Likelihood:                 15261.
# No. Observations:                 506   AIC:                        -3.049e+04
# Df Residuals:                     491   BIC:                        -3.043e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.765e-14   2.21e-14      0.797      0.426   -2.58e-14    6.12e-14
# ...

# %% [markdown]
# # 조건수
#
# 1. 스케일링을 해주어야함.
# 2. 다중 공선성(독립 변수 간에 상관관계가 큰 경우)이 큰 경우에는 차원축소를 해주어야함.
